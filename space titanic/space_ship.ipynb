# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_train = pd.read_csv('spaceship_titanic/train.csv')

# %%
df_test = pd.read_csv('spaceship_titanic/test.csv')

# %%
df_train
# Out:
#      PassengerId HomePlanet CryoSleep     Cabin    Destination   Age    VIP  \
# 0        0001_01     Europa     False     B/0/P    TRAPPIST-1e  39.0  False
# 1        0002_01      Earth     False     F/0/S    TRAPPIST-1e  24.0  False
# 2        0003_01     Europa     False     A/0/S    TRAPPIST-1e  58.0   True
# 3        0003_02     Europa     False     A/0/S    TRAPPIST-1e  33.0  False
# 4        0004_01      Earth     False     F/1/S    TRAPPIST-1e  16.0  False
# ...          ...        ...       ...       ...            ...   ...    ...
# 8688     9276_01     Europa     False    A/98/P    55 Cancri e  41.0   True
# 8689     9278_01      Earth      True  G/1499/S  PSO J318.5-22  18.0  False
# 8690     9279_01      Earth     False  G/1500/S    TRAPPIST-1e  26.0  False
# 8691     9280_01     Europa     False   E/608/S    55 Cancri e  32.0  False
# 8692     9280_02     Europa     False   E/608/S    TRAPPIST-1e  44.0  False
#
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8693 entries, 0 to 8692
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PassengerId   8693 non-null   object
#  1   HomePlanet    8492 non-null   object
#  2   CryoSleep     8476 non-null   object
#  3   Cabin         8494 non-null   object
#  4   Destination   8511 non-null   object
#  5   Age           8514 non-null   float64
#  6   VIP           8490 non-null   object
#  7   RoomService   8512 non-null   float64
#  8   FoodCourt     8510 non-null   float64
#  9   ShoppingMall  8485 non-null   float64
#  10  Spa           8510 non-null   float64
#  11  VRDeck        8505 non-null   float64
#  12  Name          8493 non-null   object
#  13  Transported   8693 non-null   bool
# dtypes: bool(1), float64(6), object(7)
# memory usage: 891.5+ KB

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8693 entries, 0 to 8692
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PassengerId   8693 non-null   object
#  1   HomePlanet    8492 non-null   object
#  2   CryoSleep     8476 non-null   object
#  3   Cabin         8494 non-null   object
#  4   Destination   8511 non-null   object
#  5   Age           8514 non-null   float64
#  6   VIP           8490 non-null   object
#  7   RoomService   8512 non-null   float64
#  8   FoodCourt     8510 non-null   float64
#  9   ShoppingMall  8485 non-null   float64
#  10  Spa           8510 non-null   float64
#  11  VRDeck        8505 non-null   float64
#  12  Name          8493 non-null   object
#  13  Transported   8693 non-null   bool
# dtypes: bool(1), float64(6), object(7)
# memory usage: 891.5+ KB

# %%
df_train['HomePlanet'].value_counts()
df_train['HomePlanet'].isnull().sum()
# Out:
# 201

# %%
df_train['HomePlanet'].loc[:5000] = df_train['HomePlanet'].loc[:5000].fillna('Earth')
df_train['HomePlanet'].loc[5000:7000] = df_train['HomePlanet'].loc[5000:7000].fillna('Europa')
df_train['HomePlanet']= df_train['HomePlanet'].fillna('Mars')

df_test['HomePlanet'].loc[:5000] = df_test['HomePlanet'].loc[:5000].fillna('Earth')
df_test['HomePlanet'].loc[5000:7000] = df_test['HomePlanet'].loc[5000:7000].fillna('Europa')
df_test['HomePlanet']= df_test['HomePlanet'].fillna('Mars')
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_1232\78349304.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_train['HomePlanet'].loc[:5000] = df_train['HomePlanet'].loc[:5000].fillna('Earth')
# ...

# %%
df_train['CryoSleep'].value_counts()
# Out:
# CryoSleep
# False    5439
# True     3037
# Name: count, dtype: int64

# %%
df_train['CryoSleep'].loc[:6000].isnull().sum()
df_test['CryoSleep'].loc[:6000].isnull().sum()
# Out:
# 93

# %%
df_train['CryoSleep'].loc[:6000] = df_train['CryoSleep'].loc[:6000].fillna(False)
df_train['CryoSleep'] = df_train['CryoSleep'].fillna(True)

df_test['CryoSleep'].loc[:6000] = df_test['CryoSleep'].loc[:6000].fillna(False)
df_test['CryoSleep'] = df_test['CryoSleep'].fillna(True)
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_1232\2244395516.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_train['CryoSleep'].loc[:6000] = df_train['CryoSleep'].loc[:6000].fillna(False)
# C:\Users\Asus\AppData\Local\Temp\ipykernel_1232\2244395516.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# ...

# %%
df_train['Destination'].value_counts()
# Out:
# Destination
# TRAPPIST-1e      5915
# 55 Cancri e      1800
# PSO J318.5-22     796
# Name: count, dtype: int64

# %%
df_train['Destination'] = df_train['Destination'].fillna('TRAPPIST-1e')
df_test['Destination'] = df_test['Destination'].fillna('TRAPPIST-1e')

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8693 entries, 0 to 8692
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PassengerId   8693 non-null   object
#  1   HomePlanet    8693 non-null   object
#  2   CryoSleep     8693 non-null   bool
#  3   Cabin         8494 non-null   object
#  4   Destination   8693 non-null   object
#  5   Age           8514 non-null   float64
#  6   VIP           8490 non-null   object
#  7   RoomService   8512 non-null   float64
#  8   FoodCourt     8510 non-null   float64
#  9   ShoppingMall  8485 non-null   float64
#  10  Spa           8510 non-null   float64
#  11  VRDeck        8505 non-null   float64
#  12  Name          8493 non-null   object
#  13  Transported   8693 non-null   bool
# dtypes: bool(2), float64(6), object(6)
# memory usage: 832.1+ KB

# %%
df_train['Age'] = df_train['Age'].interpolate()
df_train['VIP'] = df_train['VIP'].interpolate()
df_train['RoomService'] = df_train['RoomService'].interpolate()
df_train['FoodCourt'] = df_train['FoodCourt'].interpolate()
df_train['ShoppingMall'] = df_train['ShoppingMall'].interpolate()
df_train['VRDeck'] = df_train['VRDeck'].interpolate()
df_train['Spa'] = df_train['Spa'].interpolate()
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_1232\2370280414.py:2: FutureWarning: Series.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df_train['VIP'] = df_train['VIP'].interpolate()

# %%
df_test['Age'] = df_test['Age'].interpolate()
df_test['VIP'] = df_test['VIP'].interpolate()
df_test['RoomService'] = df_test['RoomService'].interpolate()
df_test['FoodCourt'] = df_test['FoodCourt'].interpolate()
df_test['ShoppingMall'] = df_test['ShoppingMall'].interpolate()
df_test['VRDeck'] = df_test['VRDeck'].interpolate()
df_test['Spa'] = df_test['Spa'].interpolate()
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_1232\2476223409.py:2: FutureWarning: Series.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df_test['VIP'] = df_test['VIP'].interpolate()

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8693 entries, 0 to 8692
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PassengerId   8693 non-null   object
#  1   HomePlanet    8693 non-null   object
#  2   CryoSleep     8693 non-null   bool
#  3   Cabin         8494 non-null   object
#  4   Destination   8693 non-null   object
#  5   Age           8693 non-null   float64
#  6   VIP           8490 non-null   object
#  7   RoomService   8693 non-null   float64
#  8   FoodCourt     8693 non-null   float64
#  9   ShoppingMall  8693 non-null   float64
#  10  Spa           8693 non-null   float64
#  11  VRDeck        8693 non-null   float64
#  12  Name          8493 non-null   object
#  13  Transported   8693 non-null   bool
# dtypes: bool(2), float64(6), object(6)
# memory usage: 832.1+ KB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4277 entries, 0 to 4276
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PassengerId   4277 non-null   object
#  1   HomePlanet    4277 non-null   object
#  2   CryoSleep     4277 non-null   bool
#  3   Cabin         4177 non-null   object
#  4   Destination   4277 non-null   object
#  5   Age           4277 non-null   float64
#  6   VIP           4184 non-null   object
#  7   RoomService   4277 non-null   float64
#  8   FoodCourt     4277 non-null   float64
#  9   ShoppingMall  4277 non-null   float64
#  10  Spa           4277 non-null   float64
#  11  VRDeck        4277 non-null   float64
#  12  Name          4183 non-null   object
# dtypes: bool(1), float64(6), object(6)
# memory usage: 405.3+ KB

# %%
df_test['Cabin'].isna().sum()
# Out:
# 100

# %%
df_test['Cabin'].value_counts()
# Out:
# Cabin
# G/160/P     8
# D/273/S     7
# B/31/P      7
# G/748/S     7
# E/228/S     7
#            ..
# E/236/S     1
# F/650/S     1
# G/566/P     1
# G/557/S     1
# G/1498/S    1
# Name: count, Length: 3265, dtype: int64

# %%
df_test['Cabin'].loc[:6000] = df_test['Cabin'].loc[:6000].fillna('D/273/S')
df_test['Cabin'] = df_test['Cabin'].fillna('B/31/P')
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_1232\2298061960.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_test['Cabin'].loc[:6000] = df_test['Cabin'].loc[:6000].fillna('D/273/S')
# ...

# %%
# df_test['Dec'] = df_test['Cabin'].apply(lambda n:n.split('/')[0])
# df_test['Num'] = df_test['Cabin'].apply(lambda n:int(n.split('/')[1]))
# df_test['Side'] = df_test['Cabin'].apply(lambda n:n.split('/')[2])

# %%
df_train = df_train.drop(['Cabin', 'Name', 'PassengerId'], axis=1)
df_test = df_test.drop(['Cabin', 'Name', 'PassengerId'], axis=1)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label = LabelEncoder()

# %%
X_train = df_train.drop('Transported', axis=1)
y_train = df_train['Transported']
X_test = df_test

# %%
for i in X_train.columns:
    if X_train[i].dtype == object:
        X_train[i] = label.fit_transform(X_train[i])

# %%
for i in X_test.columns:
    if X_test[i].dtype == object:
        X_test[i] = label.fit_transform(X_test[i])

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier

# %%
scaler = StandardScaler()

# %%
model = RandomForestClassifier()

# %%
pipe = Pipeline([('scaler', scaler), ('model',model)])

# %%
params = {
    'model__criterion':["gini", "entropy", "log_loss"],
    'model__n_estimators':[60,80,100,120],
    'model__max_features':["sqrt", "log2", None],
    'model__bootstrap':[True,False],
    'model__oob_score':[True,False],
    'model__max_depth':[3,5,10,None]
    
}

# %%
full_model = GridSearchCV(pipe,param_grid=params,cv=3,verbose=2,scoring='accuracy')

# %%
full_model.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 576 candidates, totalling 1728 fits
# [CV] END model__bootstrap=True, model__criterion=gini, model__max_depth=3, model__max_features=sqrt, model__n_estimators=60, model__oob_score=True; total time=   0.3s
# [CV] END model__bootstrap=True, model__criterion=gini, model__max_depth=3, model__max_features=sqrt, model__n_estimators=60, model__oob_score=True; total time=   0.3s
# [CV] END model__bootstrap=True, model__criterion=gini, model__max_depth=3, model__max_features=sqrt, model__n_estimators=60, model__oob_score=True; total time=   0.3s
# [CV] END model__bootstrap=True, model__criterion=gini, model__max_depth=3, model__max_features=sqrt, model__n_estimators=60, model__oob_score=False; total time=   0.2s
# [CV] END model__bootstrap=True, model__criterion=gini, model__max_depth=3, model__max_features=sqrt, model__n_estimators=60, model__oob_score=False; total time=   0.2s
# ...

# %%
full_model.best_params_
# Out:
# {'model__bootstrap': True,
#  'model__criterion': 'log_loss',
#  'model__max_depth': 10,
#  'model__max_features': 'log2',
#  'model__n_estimators': 60,
#  'model__oob_score': True}

# %%
y_pred = full_model.predict(X_test)

# %%
sub = pd.read_csv('spaceship_titanic/sample_submission.csv')

# %%
sub
# Out:
#      PassengerId  Transported
# 0        0013_01        False
# 1        0018_01        False
# 2        0019_01        False
# 3        0021_01        False
# 4        0023_01        False
# ...          ...          ...
# 4272     9266_02        False
# 4273     9269_01        False
# 4274     9271_01        False
# 4275     9273_01        False
# 4276     9277_01        False
#
# [4277 rows x 2 columns]

# %%
sub['Transported'] = y_pred

# %%
sub.to_csv('space_model.csv',index=False,index_label=False)

# %%
#0.79494
